# %%
import numpy as np
import CellModeller
from CellModeller.Simulator import Simulator

# %%
model = '/Users/timrudge/cellmodeller/Examples/ex1_simpleGrowth.py'
sim = Simulator(model, 0.025, clPlatformNum=0, clDeviceNum=0, saveOutput=True)
# Out:
# Set up OpenCL context:
#   Platform: Apple
#   Device: Intel(R) Core(TM) i7-3820QM CPU @ 2.70GHz
# Importing model ex1_simpleGrowth
# Running in batch mode: no display will be output
# /Users/timrudge/anaconda2/envs/cellmodeller/lib/python2.7/site-packages/pyopencl/__init__.py:61: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   "to see more.", CompilerWarning)

# %%
# Run the simulation to ~500 cells
while len(sim.cellStates)<500:
    sim.step()
# Out:
#       10           6 cells           3 contacts
#    10     6 cells       3 cts       1 iterations  residual = 0.000001
#       20           6 cells           3 contacts
#    20     6 cells       3 cts       1 iterations  residual = 0.000001
#       30           6 cells           3 contacts
#    30     6 cells       3 cts       1 iterations  residual = 0.000001
#       40           6 cells           3 contacts
#    40     6 cells       3 cts       1 iterations  residual = 0.000010
#       50          12 cells           9 contacts
#    50    12 cells       9 cts       1 iterations  residual = 0.000217
#       60          12 cells           8 contacts
#    60    12 cells       8 cts       1 iterations  residual = 0.000073
#       70          12 cells           8 contacts
#    70    12 cells       8 cts       1 iterations  residual = 0.000135
#       80          12 cells           8 contacts
#    80    12 cells       8 cts       1 iterations  residual = 0.000010
#       90          24 cells          23 contacts
#    90    24 cells      22 cts       1 iterations  residual = 0.000221
#    90    24 cells      24 cts       1 iterations  residual = 0.000216
#    90    24 cells      25 cts       0 iterations  residual = 0.000248
#      100          24 cells          27 contacts
#   100    24 cells      27 cts       1 iterations  residual = 0.000438
#   100    24 cells      28 cts       0 iterations  residual = 0.000579
#      110          24 cells          30 contacts
#   110    24 cells      29 cts       2 iterations  residual = 0.000142
#   110    24 cells      31 cts       0 iterations  residual = 0.000300
#      120          24 cells          40 contacts
#   120    25 cells      38 cts       2 iterations  residual = 0.000181
#   120    25 cells      41 cts       1 iterations  residual = 0.000262
#      130          43 cells          77 contacts
#   130    44 cells      79 cts       3 iterations  residual = 0.000673
#   130    44 cells      80 cts       0 iterations  residual = 0.000900
#      140          48 cells          94 contacts
#   140    48 cells      88 cts       2 iterations  residual = 0.001058
#   140    48 cells      93 cts       1 iterations  residual = 0.001134
#      150          48 cells          98 contacts
#   150    48 cells      95 cts       3 iterations  residual = 0.000436
#   150    48 cells      99 cts       0 iterations  residual = 0.001123
#      160          49 cells         107 contacts
#   160    50 cells     106 cts       3 iterations  residual = 0.000886
#   160    50 cells     108 cts       2 iterations  residual = 0.000921
#   160    50 cells     109 cts       0 iterations  residual = 0.000797
#      170          78 cells         181 contacts
#   170    82 cells     179 cts       5 iterations  residual = 0.000929
#   170    82 cells     182 cts       0 iterations  residual = 0.001938
#      180          96 cells         225 contacts
#   180    96 cells     225 cts       5 iterations  residual = 0.001350
#   180    96 cells     229 cts       1 iterations  residual = 0.002376
#      190          96 cells         246 contacts
#   190    96 cells     244 cts       5 iterations  residual = 0.001157
#   190    96 cells     248 cts       2 iterations  residual = 0.002118
#      200          96 cells         268 contacts
#   200    96 cells     262 cts       4 iterations  residual = 0.002382
#   200    96 cells     268 cts       3 iterations  residual = 0.002061
#      210         126 cells         351 contacts
#   210   130 cells     350 cts       8 iterations  residual = 0.002507
#   210   130 cells     359 cts       5 iterations  residual = 0.002422
#   210   130 cells     362 cts       1 iterations  residual = 0.003100
#      220         178 cells         486 contacts
#   220   180 cells     481 cts       6 iterations  residual = 0.004086
#   220   180 cells     491 cts       5 iterations  residual = 0.003207
#   220   180 cells     492 cts       1 iterations  residual = 0.003080
#      230         192 cells         571 contacts
#   230   192 cells     560 cts       7 iterations  residual = 0.004075
#   230   192 cells     570 cts       5 iterations  residual = 0.002284
#   230   192 cells     572 cts       1 iterations  residual = 0.003894
#      240         192 cells         592 contacts
#   240   192 cells     583 cts       7 iterations  residual = 0.003420
#   240   192 cells     592 cts       5 iterations  residual = 0.002780
#      250         201 cells         626 contacts
#   250   206 cells     623 cts       7 iterations  residual = 0.004703
#   250   206 cells     633 cts       5 iterations  residual = 0.004160
#   250   206 cells     634 cts       4 iterations  residual = 0.004717
#      260         263 cells         806 contacts
#   260   267 cells     813 cts       8 iterations  residual = 0.005964
#   260   267 cells     822 cts       6 iterations  residual = 0.003937
#      270         313 cells         978 contacts
#   270   316 cells     970 cts       8 iterations  residual = 0.007127
#   270   316 cells     981 cts       6 iterations  residual = 0.007412
#   270   316 cells     984 cts       4 iterations  residual = 0.007285
#      280         345 cells        1098 contacts
#   280   347 cells    1090 cts       9 iterations  residual = 0.006027
#   280   347 cells    1104 cts       6 iterations  residual = 0.006285
#   280   347 cells    1106 cts       1 iterations  residual = 0.007203
#      290         367 cells        1190 contacts
#   290   371 cells    1198 cts      10 iterations  residual = 0.006837
#   290   371 cells    1206 cts       6 iterations  residual = 0.009234
#   290   371 cells    1209 cts       1 iterations  residual = 0.008088
#   290   371 cells    1210 cts       0 iterations  residual = 0.009165
#      300         416 cells        1337 contacts
#   300   417 cells    1331 cts       9 iterations  residual = 0.009489
#   300   417 cells    1342 cts       6 iterations  residual = 0.009729
#   300   417 cells    1345 cts       1 iterations  residual = 0.010111
#   300   417 cells    1346 cts       1 iterations  residual = 0.007870
#      310         466 cells        1524 contacts
#   310   475 cells    1530 cts      10 iterations  residual = 0.010645
#   310   475 cells    1544 cts       7 iterations  residual = 0.006498
#   310   475 cells    1548 cts       1 iterations  residual = 0.010485
#   310   475 cells    1549 cts       1 iterations  residual = 0.008744
#   310   475 cells    1550 cts       0 iterations  residual = 0.011253

# %%
print sim.phys.n_cells
print sim.stepNum

# We can get the data directly from the running simulation
cs = sim.cellStates

# or from a saved pickle file
import cPickle
data = cPickle.load(open('/Users/timrudge/cellmodeller/data/ex1_simpleGrowth-17-11-17-14-00/step-00500.pickle','rb'))
cs = data['cellStates']

# Make some convenient data arrays from cell properties
lengths = np.array([cell.length for (id,cell) in cs.iteritems()])
pos = np.array([cell.pos for (id,cell) in cs.iteritems()])
norm = np.array([cell.dir for (id,cell) in cs.iteritems()])
# Out:
# 503
# 315

# %%
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

# Plot the position and orientation of each cell
plt.figure(figsize=(8,8))
plt.plot(pos[:,0], pos[:,1], 'o')
plt.quiver(pos[:,0], pos[:,1], norm[:,0], norm[:,1])

# %%
# Plot histograms of some cell properties

# Length
plt.subplot(121)
plt.title('Length')
plt.hist(lengths)

# Distance from origin
plt.subplot(122)
plt.title('Position')
plt.hist(np.sqrt(pos[:,0]**2+pos[:,1]**2))
# Out:
# (array([  20.,   50.,   89.,  118.,  137.,  167.,  195.,  204.,  205.,   71.]),
#  array([  0.71793818,   4.43772304,   8.1575079 ,  11.87729275,
#          15.59707761,  19.31686246,  23.03664732,  26.75643218,
#          30.47621703,  34.19600189,  37.91578674]),
#  <a list of 10 Patch objects>)

# %%
# Compute the cell density in regular bins as a weighted 2d histogram

fig = plt.figure()
H, xedges, yedges = np.histogram2d(pos[:,0], pos[:,1], weights=lengths, bins=16)
plt.imshow(H, interpolation='nearest', origin='low', extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
plt.colorbar()

# %%
# We can also examine the details of the running simulation,
# e.g. the residual overlaps between cells (error)

# Get the physics solver
phys = sim.phys
# Update the contact information
phys.find_contacts()
# Overlap per cell
d = 0.5*phys.ct_dists_dev[0:phys.n_cells,:].get()

# Min and max of overlap
print np.min(d.ravel()), np.max(d.ravel())
# Out:
# -0.0879959 0.0602031
